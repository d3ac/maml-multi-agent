# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Train

# %%
data = pd.read_excel('output/train.xlsx')
data = np.array(data)
plt.plot(data) 
plt.xlabel('iteration')
plt.ylabel('return')
plt.title('train')
# Out:
# Text(0.5, 1.0, 'train')

# %%
data = pd.read_excel('output/valid.xlsx')
data = np.array(data)
plt.plot(data)
plt.xlabel('iteration')
plt.ylabel('return')
plt.title('valid')
# Out:
# Text(0.5, 1.0, 'valid')

# %% [markdown]
# ## Test

# %%
data = np.load('output/results.npz')
train = data['train_returns']
test =  data['valid_returns']
print(f'train: {train}, mean:{np.mean(train)}\n')
print(f'test: {test}, mean{np.mean(test)}\n')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = np.load('output/results.npz')
#       2 train = data['train_returns']
#       3 test =  data['valid_returns']
#
# File ~/miniconda3/lib/python3.8/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/results.npz'
